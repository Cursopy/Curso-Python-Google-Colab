# %% [markdown]
# # **Iteradores**
#
# **Iterables:** Objetos por los cuales se puede iterar, se puede recorrer sus elementos 1 a 1 mediante un ciclo.
#
# **Iterador:** Permiten recorrer los elementos de una secuencia pero accediendo a los valores 1 a 1 solo cuando se van necesitando. *LOS ITERADORES TAMBIÉN SON ITERABLES.*

# %%
x = [0, 1, 2, 3, 4, 5]
y = iter(range(6))

print(type(x), type(y))
# Out:
# <class 'list'> <class 'range_iterator'>

# %%
next(y)
# Out:
# 0

# %%
next(y)
# Out:
# 1

# %%
for elemento in x:
  print(elemento)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for elemento in y:
  print(elemento)
# Out:
# 2
# 3
# 4
# 5

# %%
#Almacenan los mismos elementos pero en el caso de 'x', accedemos a los elementos
#mediante una lista, y en el caso de 'y' accedemos a ellos solo cuando los necesitamos.

#Los iteradores sirven para ahorrar memoria en los programas.

# %%
next(y)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-81b9d2f0f16a> in <module>()
# ----> 1 next(y)
#
# StopIteration:

# %%
[elemento for elemento in range(10000000000000000000000)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-639e9a6f577b> in <module>()
# ----> 1 [elemento for elemento in range(10000000000000000000000)]
#
# <ipython-input-9-639e9a6f577b> in <listcomp>(.0)
# ----> 1 [elemento for elemento in range(10000000000000000000000)]
#
# KeyboardInterrupt:

# %%
a = iter(range(10000000000000000000000))

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
help(reversed)
# Out:
# Help on class reversed in module builtins:
#
# class reversed(object)
#  |  reversed(sequence) -> reverse iterator over values of the sequence
#  |
#  |  Return a reverse iterator
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __length_hint__(...)
#  |      Private method returning an estimate of len(list(it)).
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __setstate__(...)
#  |      Set state information for unpickling.

# %%
lista = [(6, 'a'), (1, 'j'), (4, 't'), (0, 'h'), (2, 'r')]
lista_inversa = reversed(lista)
print(lista_inversa)

# %%
for elemento in lista_inversa:
  print(elemento)
# Out:
# (2, 'r')
# (0, 'h')
# (4, 't')
# (1, 'j')
# (6, 'a')

# %%
next(lista_inversa)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-23-8a7cb8c2ae7a> in <module>()
# ----> 1 next(lista_inversa)
#
# StopIteration:

# %%
# Zip()

alumnos = ['Daniela', 'Mariana', "Carla", 'Maria']
edades = [26, 27, 28, 29, 30]
notas = [10, 11, 12, 13, 14, 15, 16, 17]

zip(alumnos, edades, notas)

# %%
for nombre, edad, nota in zip(alumnos, edades, notas):
  print('El alumno {} tiene {} años de edad y su calificacion es de {}'.format(nombre, edad, nota))
# Out:
# El alumno Daniela tiene 26 años de edad y su calificacion es de 10
# El alumno Mariana tiene 27 años de edad y su calificacion es de 11
# El alumno Carla tiene 28 años de edad y su calificacion es de 12
# El alumno Maria tiene 29 años de edad y su calificacion es de 13

# %%
list(zip(alumnos, edades, notas))
# Out:
# [('Daniela', 26, 10),
#  ('Mariana', 27, 11),
#  ('Carla', 28, 12),
#  ('Maria', 29, 13)]

# %%
dict(zip(alumnos, notas))
# Out:
# {'Carla': 12, 'Daniela': 10, 'Maria': 13, 'Mariana': 11}

# %%
#map

def cuadrado(numero):
  return pow(numero, 2)

a = map(cuadrado, [1, 2, 3, 4, 5])

# %%
a

# %%
list(a)
# Out:
# [1, 4, 9, 16, 25]

# %%
# Crear una lista que contenga los numeros del 1 al 10 y para aquellos
# numeros que sean pares devuelva la palabra 'par'.

def chequeo_par(numero):
  if numero % 2 == 0:
    return 'par'
  else:
    return numero

lista = map(chequeo_par, range(1, 11))
print(lista)

# %%
list(lista)
# Out:
# [1, 'par', 3, 'par', 5, 'par', 7, 'par', 9, 'par']

# %%
lista = list(map(lambda x: 'par' if x % 2 == 0 else x, range(1, 11)))
lista
# Out:
# [1, 'par', 3, 'par', 5, 'par', 7, 'par', 9, 'par']

# %%
list(map(lambda x: x[::-1], ['Brillo', 'Amarillo', 'Colores']))
# Out:
# ['ollirB', 'olliramA', 'seroloC']

# %%
#filter

tuple(filter(lambda x: True if len(x) % 2 == 0 else False, ['Brillo', 'Amarillo', 'Colores']))

#Devolvera aquellos elementos cuyo resultado de la funcion sean True. Es un 
#iterador lógico.
# Out:
# ('Brillo', 'Amarillo')

# %%
list(filter(lambda x: True if len(x) % 2 == 0 else False, ['Ronny', 'Eve', 'David', 'Rebe']))
# Out:
# ['Rebe']

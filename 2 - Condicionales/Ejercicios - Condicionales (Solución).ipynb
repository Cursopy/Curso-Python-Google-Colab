# %% [markdown]
# # Ejercicio 1.

# %% [markdown]
# Escribe un programa en Python usando condicionales que sea capaz de llevar a cabo el juego de **Piedra, Papel o Tijeras** entre un jugador real y la computadora.
#
# 1. Crea una variable llamada `opciones` la cual será de tipo `lista` y allí almacenaras las palabras **Piedra, Papel, Tijeras.**
#
# 2. Del módulo `random` importa la función `randint()`.
#
# 3. A una variable llamada `computadora` asígnale un valor aleatorio de la variable `opciones`, es decir, `computadora = opciones[????]` dentro de los corchetes deberás hacer uso de la función `randint()` para tomar aleatoriamente un elemento entre los índices de la lista `opciones`.
#
# 4. Realiza el programa considerando lo siguiente:
#
#   4.1. Deberás solicitarle al usuario su opción mediante una función `input()`.
#
#   4.2. Si la opción de la computadora es igual a la opción del usuario, la salida del programa deberá ser `Empate`.
#
#   4.3. Si la opción de la computadora es distinta a la del usuario deberás chequear quien ha ganado. Posteriormente, deberás imprimir un mensaje que muestre si el usuario ganó o perdió. En caso de que la computadora haya ganado, mostrar su alternativa.
#
#   4.4. Si el usuario ingresa una opción incorrecta, deberá mostrarle un mensaje que diga que la opción es incorrecta y que debe intentar de nuevo.
#
# *Pista: Recuerda que a la piedra solo le gana el papel, es decir que si el usuario escoge piedra, se deberá chequear si la opción de la computadora es papel. Si la alternativa de la computadora fuera papel entonces gana la computadora, de lo contrario gana el usuario. Análogamente con el resto de las opciones.*

# %%
from random import randint
opciones = ['piedra', 'papel', 'tijeras']
computadora = opciones[randint(0, 2)]

jugador = input('Ingresa tu opción: [Piedra, Papel, Tijeras]\n--> ').lower()

if jugador == computadora:
  print(f'\nEmpate! Ambos escogieron {jugador}.')

elif jugador == 'piedra':
  if computadora == 'papel':
    print(f'\nPerdiste! 😪 la computadora ha sacado {computadora}🧻')
  else:
    print(f'\nGanaste! 🤗 Aplastaste a la computadora.')

elif jugador == 'papel':
  if computadora == 'tijeras':
    print(f'\nPerdiste! 😪 la computadora ha sacado {computadora}✂')
  else:
    print(f'\nGanaste! 🤗 Cubriste a la computadora.')

elif jugador == 'tijeras':
  if computadora == 'piedra':
    print(f'\nPerdiste! 😪 la computadora ha sacado {computadora}.')
  else:
    print(f'\nGanaste! 🤗 Cortaste a la computadora.')

else:
  print('\nOpción incorrecta, intenta de nuevo.')
# Out:
# Ingresa tu opción: [Piedra, Papel, Tijeras]
# --> uierhgeuihr
#
# Opción incorrecta, intenta de nuevo.

# %% [markdown]
# # Ejercicio 2.

# %% [markdown]
# Escribe un programa en Python para simular un cajero automático. Al momento de correr el programa deberá mostrar un menú con 4 opciones:
#
# 1. Saldo actual
# 2. Retiro
# 3. Depositar
# 4. Salir
#
# *   Cree una variable antes de toda la lógica del programa que se llame saldo y sea igual a 5000.
# *   Las unidades para el dinero deberán estar en dólares 💲.
# *   Desde la opción 1 a la opción 3 deberá mostrar el saldo actual.
# *   En la opción de retiro deberá ser capaz de corroborar que la cantidad no supera al saldo actual y tampoco es una cantidad negativa. Además, deberá mostrar la cantidad retirada y el saldo actual luego del retiro.
# *   En la opción de depósito deberá corroborar que la cantidad no sea negativa. Así mismo, debe mostrar el saldo depositado y el saldo total luego del depósito.
# *   Asegurarse de que si el usuario ingresa una cantidad incorrecta se le muestre un mensaje acorde a la situación.

# %%
print('Cajero automático')
print('-----------------')
print('''
1. Saldo actual
2. Retiro
3. Depositar
4. Salir
''')

saldo = 5000
opcion = int(input('Ingresa tu opción:\n--> '))

if opcion == 1:
  print(f'\nTu saldo actual es de: ${saldo}')

elif opcion == 2:
  print(f'\nTu saldo actual es de: ${saldo}')
  retiro = float(input('\nIngresa el monto a retirar:\n--> $'))

  if retiro > 0 and retiro <= saldo:
    print(f'\nHas retirado: ${retiro}')
    print(f'Saldo actual: ${saldo - retiro}')
  else:
    print('\nCantidad inválida o superior al saldo disponible.')

elif opcion == 3:
  print(f'\nTu saldo actual es de: ${saldo}')
  deposito = float(input('\nIngresa la cantidad a depositar:\n--> $'))

  if deposito > 0:
    print(f'\nHas depositado: ${deposito}')
    print(f'Saldo actual: ${saldo + deposito}')
  else:
    print('\nCantidad inválida')

elif opcion == 4:
  print('\nGracias por usar nuestro servicio. Hasta pronto!')

else:
  print('\nIngresa una opción válida')
# Out:
# Cajero automático
# -----------------
#
# 1. Saldo actual
# 2. Retiro
# 3. Depositar
# 4. Salir
#
# Ingresa tu opción:
# --> 1
#
# Tu saldo actual es de: $5000

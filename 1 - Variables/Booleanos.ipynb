# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True.bit_length()
# Out:
# 1

# %%
False.bit_length()
# Out:
# 0

# %%
True.numerator
# Out:
# 1

# %%
True.denominator
# Out:
# 1

# %%
1 + True
# Out:
# 2

# %%
2 + False
# Out:
# 2

# %%
complex(True, False).conjugate()
# Out:
# (1-0j)

# %%
[1, 2, 3, True]
# Out:
# [1, 2, 3, True]

# %%
len([1, 2, 3, True])
# Out:
# 4

# %% [markdown]
# # Importancia
#
#   1. Operadores aritméticos.
#   2. Operadores de comparación.
#   3. Operadores lógicos.

# %%
2 + 2 == 4
# Out:
# True

# %%
8 >= 8
# Out:
# True

# %%
9 < 12
# Out:
# True

# %%
1 < 0
# Out:
# False

# %%
1 <= 1.00000000001
# Out:
# True

# %%
10 != 3 * 3 + 1
# Out:
# False

# %%
1 == 0.9
# Out:
# False

# %%
1 == 0.999999
# Out:
# False

# %%
# Veinticinco más doce es mayor que trece menos veintiuno

25 + 12 > 13 - 21

# 37 > -8
# Out:
# True

# %%
# 3 por 5 distinto de 5 por 3 

3 * 5 != 5 * 3

# 15 != 15
# Out:
# False

# %%
6 + 2 * 5 == 9 / 3 * 7 

# 6 + 10 == 3 * 7
# 16 == 21
# Out:
# False

# %%
8 + 2 * 5 == 9 / 3 * 6
# Out:
# True

# %%
2*3 + 6*7 == 12*1 - 32*3

# 6 + 42 == 12 - 96
# 48 == -84
# Out:
# False

# %%
a = [3, 2, 5, 6, 4, True, False]

a.sort()

# %%
print(a)
# Out:
# [False, True, 2, 3, 4, 5, 6]

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
not not not True
# Out:
# False

# %%
not 5 + 5 == 10

# not 10 == 10
# not True
# Out:
# False

# %%
not 1 == 0
# Out:
# True

# %%
not 4 + 4 > 3 * 4
# Out:
# True

# %%
# El operador 'and' une dos sentencias logicas y devolvera 'True'
# si ambas son verdaderas, de lo contrario devolvera 'False'.

# %%
# Tabla de verdad -> Truth Table

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True and 2 == 1
# Out:
# False

# %%
2 + 2 == 4 and 4 > 3
# Out:
# True

# %%
# 5 es mayor que 9 y 4 es menor que 3

5 > 9 and 4 < 3
# Out:
# False

# %%
(16 * True + False) >= (True * 8) and 12 ** False != 12 * 0 + 2 


# 16 >= 8 and 1 != 2
# True and True
# Out:
# True

# %%
# El operador 'or' une dos sentencias logicas y devolvera 'True'
# si una es verdadera, de lo contrario devolvera 'False'.

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
2 + 2 == 4 or 5 > 5
# Out:
# True

# %%
2 + 2 != 4 or 5 > 5
# Out:
# False

# %%
(16 * True + False) >= (True * 8) or 12 ** False != 12 * 0 + 2
# Out:
# True

# %%
# No es que 2 mas 2 sea igual a 5 o que 8 sea mayor que 3

not 2 + 2 == 5 or 8 > 3

# not 4 == 5 or 8 > 3
# not False or True
# True or True
# Out:
# True

# %%
not (2 + 2 == 5 or 8 > 3)
# Out:
# False

# %%
# 5 por 2 mayor igual que 11 y no es que 4 sea mayor que 5

5 * 2 >= 11 and not 4 > 5
# Out:
# False

# %%
1*True == 2 and 4+2 == 5 or 3*True != 5

# False and False or True
# False or True
# Out:
# True

# %%
a = True
b = True

c = {'uno': 1, 'dos': 2}
d = {'uno': 1, 'dos': 2}

# %%
print(id(a), id(b))
# Out:
# 10302848 10302848

# %%
print(id(c), id(d))
# Out:
# 140278541479152 140278541010264

# %%
a is b
# Out:
# True

# %%
c is d
# Out:
# False

# %%
a = (6, True, 'tupla', 2.1, [1, 2, 3], 6)

# %%
type(a)
# Out:
# tuple

# %%
a.count(6)
# Out:
# 2

# %%
a.index(6)
# Out:
# 0

# %%
b = (1, 2, 3, 4)
c = (5, 6, 7, 8)

b + c
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8)

# %%
c + b
# Out:
# (5, 6, 7, 8, 1, 2, 3, 4)

# %%
b += c + ('hola', 5)

# %%
print(b)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 'hola', 5)

# %%
print(a)
# Out:
# (6, True, 'tupla', 2.1, [1, 2, 3], 6)

# %%
a *= 3

# %%
print(a)
# Out:
# (6, True, 'tupla', 2.1, [1, 2, 3], 6, 6, True, 'tupla', 2.1, [1, 2, 3], 6, 6, True, 'tupla', 2.1, [1, 2, 3], 6)

# %%
tuple([1, 2, 3, 4])
# Out:
# (1, 2, 3, 4)

# %%
tuple('Maria Jose')
# Out:
# ('M', 'a', 'r', 'i', 'a', ' ', 'J', 'o', 's', 'e')

# %%
tuple({'nombre': 'ronny', 'edad': 26})
# Out:
# ('nombre', 'edad')

# %%
a
# Out:
# (6,
#  True,
#  'tupla',
#  2.1,
#  [1, 2, 3],
#  6,
#  6,
#  True,
#  'tupla',
#  2.1,
#  [1, 2, 3],
#  6,
#  6,
#  True,
#  'tupla',
#  2.1,
#  [1, 2, 3],
#  6)

# %%
print(a)
# Out:
# (6, True, 'tupla', 2.1, [1, 2, 3], 6, 6, True, 'tupla', 2.1, [1, 2, 3], 6, 6, True, 'tupla', 2.1, [1, 2, 3], 6)

# %%
a[:6]
# Out:
# (6, True, 'tupla', 2.1, [1, 2, 3], 6)

# %%
a[2]
# Out:
# 'tupla'

# %%
print(a[::-1])
# Out:
# (6, [1, 2, 3], 2.1, 'tupla', True, 6, 6, [1, 2, 3], 2.1, 'tupla', True, 6, 6, [1, 2, 3], 2.1, 'tupla', True, 6)

# %%
a[2::3]
# Out:
# ('tupla', 6, 'tupla', 6, 'tupla', 6)

# %%
a[1:2]
# Out:
# (True,)

# %%
type((2))
# Out:
# int

# %%
(2+2) * (4)
# Out:
# 16

# %%
type((2,))
# Out:
# tuple

# %%
# Crea una tupla que contenga únicamente aquellos modelos de autos 
# que comiencen por la  letra 'F' a partir de las siguientes tuplas:

carros1 = ('Stelvio', ' Giulia', 'Aveo', 'Fiesta')

carros2 = ('Veyron 16.4', 'Focus', 'Ateca', 'Tucson')

carros3 = ('Forester', 'Ibiza', 'Fabia', 'Clio')

carros = carros1[-1] + carros2[1] + carros3[-2]
print(carros)
# Out:
# FiestaFocusFabia

# %%
# Forma 1

carros = (carros1[-1],) + (carros2[1],) + (carros3[-2],)
print(carros)
# Out:
# ('Fiesta', 'Focus', 'Fabia')

# %%
# Forma 2

carros = (carros1[-1], carros2[1], carros3[-2])
print(carros)
# Out:
# ('Fiesta', 'Focus', 'Fabia')

# %%
# Forma 3

carros = carros1[-1:] + carros2[1:2] + carros3[-2:-1]
print(carros)
# Out:
# ('Fiesta', 'Focus', 'Fabia')

# %%
a = [1, 2, 3, 4]
b = ['a', 'b', 'c', 'd']

zip(a, b)

# %%
tuple(zip(a, b))
# Out:
# ((1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'))

# %%
list(zip(a, b))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]

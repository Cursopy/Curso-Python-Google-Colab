# %%
import math

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.sin(0)
# Out:
# 0.0

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.ceil(6.1)
# Out:
# 7

# %%
math.floor(6.1)
# Out:
# 6

# %%
from math import acos, pi

# %%
acos(0)
# Out:
# 1.5707963267948966

# %%
pi
# Out:
# 3.141592653589793

# %%
from statistics import mean

# %%
mean([1, 2, 3, 4, 4, 7])
# Out:
# 3.5

# %%
from time import time

time()
# Out:
# 1598679881.4963303

# %%
time()
# Out:
# 1598679899.2553582

# %%
inicio = time()

[tiempo for tiempo in range(100000000)]

final = time()

print(final - inicio)
# Out:
# 10.86007571220398

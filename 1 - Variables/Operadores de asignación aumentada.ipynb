# %% [markdown]
# **Los operadores de asignación aumentada**
#
#
# | Operación | Equivalencia |
# |-----------|--------------|
# | a = a + 1 | a += 1       |
# | a = a - 1 | a -= 1       |
# | a = a * 1 | a *= 1       |
# | a = a / 1 | a /= 1       |
# | a = a % 1 | a %= 1       |

# %%
a = 4

# %%
a = a + 5

# %%
a
# Out:
# 9

# %%
a += 5

# %%
a
# Out:
# 14

# %%
b = 5

# %%
b /= 5 # b = b / 5

# %%
b
# Out:
# 1.0

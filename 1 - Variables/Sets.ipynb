# %%
a = {1, 2.0, 'hola', (1, 2, 3)}
type(a)
# Out:
# set

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-8bc71255a22e> in <module>()
# ----> 1 a[1]
#
# TypeError: 'set' object does not support indexing

# %%
{1, 2, 3, 5, 9, 0, 4, 4, 4, 4}
# Out:
# {0, 1, 2, 3, 4, 5, 9}

# %%
set()
# Out:
# set()

# %%
set('Curso Python')
# Out:
# {' ', 'C', 'P', 'h', 'n', 'o', 'r', 's', 't', 'u', 'y'}

# %%
set([1, 2, 3, 4])
# Out:
# {1, 2, 3, 4}

# %%
set([1, 2, 3, 4, 2.0, 'hola', (1, 2, 3)])
# Out:
# {(1, 2, 3), 1, 2, 3, 4, 'hola'}

# %%
set([1, 2, 3, 4, (1, 2, 3, {'pais': 'venezuela'})])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eae096483228> in <module>()
# ----> 1 set([1, 2, 3, 4, (1, 2, 3, {'pais': 'venezuela'})])
#
# TypeError: unhashable type: 'dict'

# %%
(1, 2, 3, {'pais': 'venezuela'})
# Out:
# (1, 2, 3, {'pais': 'venezuela'})

# %%
a = {1, 2, 3}
b = {4, 5, 6}

a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1be0d01ce510> in <module>()
#       2 b = {4, 5, 6}
#       3
# ----> 4 a + b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a *= 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-6f1b62cac108> in <module>()
# ----> 1 a *= 3
#
# TypeError: unsupported operand type(s) for *=: 'set' and 'int'

# %%
set1 = {1, 2.0, ('hola', 3.14), 'Riemann'}
set2 = {2.0, (6, 2.71, 'euler'), 1}

print(len(set1), len(set2))
# Out:
# 4 3

# %%
a = {1, 2, 3, 4}
b = {1, 2, 3, 4}

print(id(a), id(b))
# Out:
# 139978134843176 139978134842728

# %%
set1.add(3)

# %%
set1
# Out:
# {('hola', 3.14), 1, 2.0, 3, 'Riemann'}

# %%
set1.add(3)

# %%
set1
# Out:
# {('hola', 3.14), 1, 2.0, 3, 'Riemann'}

# %%
set1 = {1, 2.0, ('hola', 3.14), 'Riemann'}
set2 = {2.0, (6, 2.71, 'euler'), 1}

set1.difference(set2)
# Out:
# {('hola', 3.14), 'Riemann'}

# %%
set3 = set1.difference(set2)
set3
# Out:
# {('hola', 3.14), 3, 'Riemann'}

# %%
set1.difference_update(set2)

# %%
set1
# Out:
# {('hola', 3.14), 1, 2.0, 'Riemann'}

# %%
set1.discard(2.0)

# %%
set1
# Out:
# {('hola', 3.14), 1, 'Riemann'}

# %%
set1.discard('hola')

# %%
set1
# Out:
# {('hola', 3.14), 1, 'Riemann'}

# %%
set1.intersection(set2)
# Out:
# {1, 2.0}

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
print(set1)
# Out:
# {1, 2.0, 'Riemann', ('hola', 3.14)}

# %%
set1.pop()
# Out:
# 1

# %%
set1
# Out:
# {('hola', 3.14), 2.0, 'Riemann'}

# %%
set1.symmetric_difference(set2)
# Out:
# {('hola', 3.14), (6, 2.71, 'euler'), 1, 'Riemann'}

# %%
set1
# Out:
# {('hola', 3.14), 2.0, 'Riemann'}

# %%
set2
# Out:
# {(6, 2.71, 'euler'), 1, 2.0}

# %%
set1.union(set2)
# Out:
# {('hola', 3.14), (6, 2.71, 'euler'), 1, 2.0, 'Riemann'}

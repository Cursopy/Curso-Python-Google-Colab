# %% [markdown]
#   - Operadores aritméticos
#
# |    Operación    |      Operador      |
# |:---------------:|:------------------:|
# |       Suma      |          +         |
# |      Resta      |          -         |
# |     Producto    |          *         |
# |     División    |          /         |
# | División entera |         //         |
# |  Residuo o Modulo |          %       |
# |  Valor absoluto |       abs()        |
# |      Entero     |       int()        |
# |  Punto flotante |      float()       |
# |     Complejo    | complex(real, img) |
# | División entera |    divmod(x, y)    |
# |   Potenciación  |         **         |
# |   Potenciación  |        pow()       |
#
# ---

# %%
x = 3
y = 5

# %%
print(x, y)
# Out:
# 3 5

# %%
x, y = (3, 5)

# %%
print(x, y)
# Out:
# 3 5

# %%
x + y
# Out:
# 8

# %%
x - y
# Out:
# -2

# %%
x * y
# Out:
# 15

# %%
x / y
# Out:
# 0.6

# %%
85 % 9
# Out:
# 4

# %%
abs(-4)
# Out:
# 4

# %%
int(4.3)
# Out:
# 4

# %%
float(3)
# Out:
# 3.0

# %%
complex(1, 4)
# Out:
# (1+4j)

# %%
complex(-4, 7)
# Out:
# (-4+7j)

# %%
complex(1, 4) * complex(1, 4)
# Out:
# (-15+8j)

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
5 // 3
# Out:
# 1

# %%
divmod(5, 3)
# Out:
# (1, 2)

# %%
2 ** 5
# Out:
# 32

# %%
pow(2, 5, 3)
# Out:
# 2

# %%
x = 3

# %%
x.denominator
# Out:
# 1

# %%
x.numerator
# Out:
# 3

# %%
x.real
# Out:
# 3

# %%
x.imag
# Out:
# 0

# %%
y = 1.4

# %%
y.is_integer()
# Out:
# False

# %%
32 % 3
# Out:
# 2

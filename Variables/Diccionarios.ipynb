# %%
persona = {
    'nombre': 'John',
    'apellido': 'Doe',
    'edad': 26,
    'id': 1234.5,
    'profesion': ('ingeniero', 'programador'),
    'certificaciones': [1, 2, 3],
    1: 'Python',
    2: 'Desarrollo web',
    3.0: 'Inteligencia artificial',
    (1, 2): 'Universidad de Venezuela',
}

# %%
print(persona)
# Out:
# {'nombre': 'John', 'apellido': 'Doe', 'edad': 26, 'id': 1234.5, 'profesion': ('ingeniero', 'programador'), 'certificaciones': [1, 2, 3], 1: 'Python', 2: 'Desarrollo web', 3.0: 'Inteligencia artificial', (1, 2): 'Universidad de Venezuela'}

# %%
persona[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-da5532f16864> in <module>()
# ----> 1 persona[0]
#
# KeyError: 0

# %%
persona['nombre']
# Out:
# 'John'

# %%
persona['profesion']
# Out:
# ('ingeniero', 'programador')

# %%
persona['id']
# Out:
# 1234.5

# %%
persona[1]
# Out:
# 'Python'

# %%
persona[3.0]
# Out:
# 'Inteligencia artificial'

# %%
persona[(1, 2)]
# Out:
# 'Universidad de Venezuela'

# %%
persona[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-60999c7014f1> in <module>()
# ----> 1 persona[0:3]
#
# TypeError: unhashable type: 'slice'

# %%
a = {
    1: 'uno',
     2: 'dos,'
}

a * {3: 'tres'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-022b11ff229c> in <module>()
#       4 }
#       5
# ----> 6 a * {3: 'tres'}
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'dict'

# %%
persona['nombre'] = 'Ronny'

# %%
print(persona)
# Out:
# {'nombre': 'Ronny', 'apellido': 'Doe', 'edad': 26, 'id': 1234.5, 'profesion': ('ingeniero', 'programador'), 'certificaciones': [1, 2, 3], 1: 'Python', 2: 'Desarrollo web', 3.0: 'Inteligencia artificial', (1, 2): 'Universidad de Venezuela'}

# %%
a.clear()

# %%
print(a)
# Out:
# {}

# %%
b = {}

# %%
print(b)
# Out:
# {}

# %%
c = dict()

# %%
print(c)
# Out:
# {}

# %%
d = persona.copy()
print(d, persona)
# Out:
# {'nombre': 'Ronny', 'apellido': 'Doe', 'edad': 26, 'id': 1234.5, 'profesion': ('ingeniero', 'programador'), 'certificaciones': [1, 2, 3], 1: 'Python', 2: 'Desarrollo web', 3.0: 'Inteligencia artificial', (1, 2): 'Universidad de Venezuela'} {'nombre': 'Ronny', 'apellido': 'Doe', 'edad': 26, 'id': 1234.5, 'profesion': ('ingeniero', 'programador'), 'certificaciones': [1, 2, 3], 1: 'Python', 2: 'Desarrollo web', 3.0: 'Inteligencia artificial', (1, 2): 'Universidad de Venezuela'}

# %%
print(id(d), id(persona))
# Out:
# 139852121646712 139852131447504

# %%
persona.get('nombre')
# Out:
# 'Ronny'

# %%
persona.get('pasaporte')

# %%
print(persona.get('pasaporte'))
# Out:
# None

# %%
persona.get('id', 'La clave no existe')
# Out:
# 1234.5

# %%
persona.items()
# Out:
# dict_items([('nombre', 'Ronny'), ('apellido', 'Doe'), ('edad', 26), ('id', 1234.5), ('profesion', ('ingeniero', 'programador')), ('certificaciones', [1, 2, 3]), (1, 'Python'), (2, 'Desarrollo web'), (3.0, 'Inteligencia artificial'), ((1, 2), 'Universidad de Venezuela')])

# %%
list(persona.items())
# Out:
# [('nombre', 'Ronny'),
#  ('apellido', 'Doe'),
#  ('edad', 26),
#  ('id', 1234.5),
#  ('profesion', ('ingeniero', 'programador')),
#  ('certificaciones', [1, 2, 3]),
#  (1, 'Python'),
#  (2, 'Desarrollo web'),
#  (3.0, 'Inteligencia artificial'),
#  ((1, 2), 'Universidad de Venezuela')]

# %%
tuple(persona.items())
# Out:
# (('nombre', 'Ronny'),
#  ('apellido', 'Doe'),
#  ('edad', 26),
#  ('id', 1234.5),
#  ('profesion', ('ingeniero', 'programador')),
#  ('certificaciones', [1, 2, 3]),
#  (1, 'Python'),
#  (2, 'Desarrollo web'),
#  (3.0, 'Inteligencia artificial'),
#  ((1, 2), 'Universidad de Venezuela'))

# %%
lista = list(persona.items())
lista[0][1]
# Out:
# 'Ronny'

# %%
persona.values()
# Out:
# dict_values(['Ronny', 'Doe', 26, 1234.5, ('ingeniero', 'programador'), [1, 2, 3], 'Python', 'Desarrollo web', 'Inteligencia artificial', 'Universidad de Venezuela'])

# %%
list(persona.values())
# Out:
# ['Ronny',
#  'Doe',
#  26,
#  1234.5,
#  ('ingeniero', 'programador'),
#  [1, 2, 3],
#  'Python',
#  'Desarrollo web',
#  'Inteligencia artificial',
#  'Universidad de Venezuela']

# %%
persona.keys()
# Out:
# dict_keys(['nombre', 'apellido', 'edad', 'id', 'profesion', 'certificaciones', 1, 2, 3.0, (1, 2)])

# %%
persona.pop('certificaciones')
# Out:
# [1, 2, 3]

# %%
persona
# Out:
# {(1, 2): 'Universidad de Venezuela',
#  1: 'Python',
#  2: 'Desarrollo web',
#  3.0: 'Inteligencia artificial',
#  'apellido': 'Doe',
#  'edad': 26,
#  'id': 1234.5,
#  'nombre': 'Ronny',
#  'profesion': ('ingeniero', 'programador')}

# %%
persona.pop('pasaporte', 'La clave no existe')
# Out:
# 'La clave no existe'

# %%
persona.popitem()
# Out:
# ((1, 2), 'Universidad de Venezuela')

# %%
persona
# Out:
# {1: 'Python',
#  2: 'Desarrollo web',
#  3.0: 'Inteligencia artificial',
#  'apellido': 'Doe',
#  'edad': 26,
#  'id': 1234.5,
#  'nombre': 'Ronny',
#  'profesion': ('ingeniero', 'programador')}

# %%
persona.setdefault('nombre')
# Out:
# 'Ronny'

# %%
persona.setdefault('pasaporte')

# %%
persona
# Out:
# {1: 'Python',
#  2: 'Desarrollo web',
#  3.0: 'Inteligencia artificial',
#  'apellido': 'Doe',
#  'edad': 26,
#  'id': 1234.5,
#  'nombre': 'Ronny',
#  'pasaporte': None,
#  'profesion': ('ingeniero', 'programador')}

# %%
persona.setdefault('pais', 100)
# Out:
# 100

# %%
persona
# Out:
# {1: 'Python',
#  2: 'Desarrollo web',
#  3.0: 'Inteligencia artificial',
#  'apellido': 'Doe',
#  'edad': 26,
#  'id': 1234.5,
#  'nombre': 'Ronny',
#  'pais': 100,
#  'pasaporte': None,
#  'profesion': ('ingeniero', 'programador')}

# %%
persona.setdefault('idiomas', ['ingles', 'chino', 'frances'])
# Out:
# ['ingles', 'chino', 'frances']

# %%
persona
# Out:
# {1: 'Python',
#  2: 'Desarrollo web',
#  3.0: 'Inteligencia artificial',
#  'apellido': 'Doe',
#  'edad': 26,
#  'id': 1234.5,
#  'idiomas': ['ingles', 'chino', 'frances'],
#  'nombre': 'Ronny',
#  'pais': 100,
#  'pasaporte': None,
#  'profesion': ('ingeniero', 'programador')}

# %%
dict.fromkeys?

# %%
elemento = ['Fe', 'H', 'He', 'Li', 'Ca', 'K', 'F']

diccionario = dict.fromkeys(elemento, 50)

print(diccionario)
# Out:
# {'Fe': 50, 'H': 50, 'He': 50, 'Li': 50, 'Ca': 50, 'K': 50, 'F': 50}

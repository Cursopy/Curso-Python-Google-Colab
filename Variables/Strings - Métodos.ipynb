# %%
x = 'camaron de la isla'

# %%
x.capitalize()
# Out:
# 'Camaron de la isla'

# %%
x.casefold()
# Out:
# 'camaron de la isla'

# %%
x = 'CAMARON de la isla'

# %%
x.casefold()
# Out:
# 'camaron de la isla'

# %%
x.lower()
# Out:
# 'camaron de la isla'

# %%
x
# Out:
# 'CAMARON de la isla'

# %%
x.lower()
# Out:
# 'camaron de la isla'

# %%
y = 'Buße'  #Penitencia

# %%
y.lower()
# Out:
# 'buße'

# %%
y.casefold()
# Out:
# 'busse'

# %%
z = 'Hector Lavoe'

# %%
z.endswith('voe')
# Out:
# True

# %%
z.endswith('VOE')
# Out:
# False

# %%
z.startswith('h')
# Out:
# False

# %%
z = 'hector Lavoe'

# %%
z.islower()
# Out:
# False

# %%
z.isupper()
# Out:
# False

# %%
z = 'HECTOR'

# %%
z.isupper()
# Out:
# True

# %%
x = '123456789ronny'
x.isnumeric()
# Out:
# False

# %%
x = '123456ronny'
x.isdigit()
# Out:
# False

# %%
x = '一二三四'

# %%
x.isdigit()
# Out:
# False

# %%
x.isnumeric()
# Out:
# True

# %%
a = 'Curso Python'

# %%
a.istitle()
# Out:
# True

# %%
a = 'curso python'
a.title()
# Out:
# 'Curso Python'

# %%
b = ' hola '
b.strip()
# Out:
# 'hola'

# %%
b.lstrip()
# Out:
# 'hola '

# %%
b.rstrip()
# Out:
# ' hola'

# %%
'Hola,.?<'.strip('<').strip('?').strip('.').strip(',')
# Out:
# 'Hola'

# %%
'ronny'.isalpha()
# Out:
# True

# %%
'?-.'.isalnum()
# Out:
# False

# %%
nombre = 'Selene Forja'

# %%
nombre.split('e')
# Out:
# ['S', 'l', 'n', ' Forja']

# %%
cadena = 'Están los que fueron y se fueron, pero siempre seguirán estando.'

# %%
print(cadena.split())
# Out:
# ['Están', 'los', 'que', 'fueron', 'y', 'se', 'fueron,', 'pero', 'siempre', 'seguirán', 'estando.']

# %%
'-'.join(cadena.split())
# Out:
# 'Están-los-que-fueron-y-se-fueron,-pero-siempre-seguirán-estando.'

# %%
print(cadena.split())
# Out:
# ['Están', 'los', 'que', 'fueron', 'y', 'se', 'fueron,', 'pero', 'siempre', 'seguirán', 'estando.']

# %%
' '.join(cadena.split())
# Out:
# 'Están los que fueron y se fueron, pero siempre seguirán estando.'

# %%
pais = 'venezuela'

pais.replace('e', 'E')
# Out:
# 'vEnEzuEla'

# %%
pais.capitalize()
# Out:
# 'Venezuela'

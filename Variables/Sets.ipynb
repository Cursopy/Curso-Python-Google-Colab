# %%
a = {1, 2, 3, 4, 5}

# %%
type(a)
# Out:
# set

# %%
{1, 2, 3, 4, 4, 4, 4, 4, 30.5, 5.7, 5.7}
# Out:
# {1, 2, 3, 4, 5.7, 30.5}

# %%
[1, 1, 1, 1, 3, 4, 5, 6]
set([1, 1, 1, 1, 3, 4, 5, 6])
# Out:
# {1, 3, 4, 5, 6}

# %%
b = {1, 1, 1, 1, 2, 3, 4, 5, 5, 5, 6.0, 6.0}
print(b)
# Out:
# {1, 2, 3, 4, 5, 6.0}

# %%
b.pop()
# Out:
# 1

# %%
print(b)
# Out:
# {2, 3, 4, 5, 6.0}

# %%
b.add('python')

# %%
b
# Out:
# {2, 3, 4, 5, 6.0, 'python'}

# %%
b.add((1, 2, 3))

# %%
b
# Out:
# {(1, 2, 3), 2, 3, 4, 5, 6.0, 'python'}

# %%
b.add((1, 2, [1, 2, 3]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-18e30e3fa6c1> in <module>()
# ----> 1 b.add((1, 2, [1, 2, 3]))
#
# TypeError: unhashable type: 'list'

# %%
b.discard(6.0)

# %%
b
# Out:
# {(1, 2, 3), 2, 3, 4, 5, 'python'}

# %%
b.discard(100)

# %%
a = {1, 2, 3, 4}
b = {1, 2, 3, 4}

print(id(a), id(b))
# Out:
# 140540213803048 140540618827368

# %%
set1 = {1, 2.0, ('hola', 3.14), 'Riemann'}
set2 = {2.0, (6, 2.71, 'euler'), 1}

print(len(set1), len(set2))
# Out:
# 4 3

# %%
set1.difference(set2)
# Out:
# {('hola', 3.14), 'Riemann'}

# %%
set1.difference_update(set2)

# %%
set1
# Out:
# {('hola', 3.14), 'Riemann'}

# %%
set1.intersection(set2)
# Out:
# {1, 2.0}

# %%
set1.union(set2)
# Out:
# {('hola', 3.14), (6, 2.71, 'euler'), 1, 2.0, 'Riemann'}

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
set1.symmetric_difference(set2)
# Out:
# {('hola', 3.14), (6, 2.71, 'euler'), 'Riemann'}

# %%
set1.update(set2)

# %%
set1
# Out:
# {('hola', 3.14), (6, 2.71, 'euler'), 1, 2.0, 'Riemann'}

# %%
set1.issubset?

# %%
se

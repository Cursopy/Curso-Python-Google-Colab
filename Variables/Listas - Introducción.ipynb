# %%
a = [1, 'python', 30.4]

# %%
# Concatenacion

a + [2.0]
# Out:
# [1, 'python', 30.4, 2.0]

# %%
a + [30, 'hola']
# Out:
# [1, 'python', 30.4, 30, 'hola']

# %%
print(a)
# Out:
# [1, 'python', 30.4]

# %%
a = a + [30, 'hola']

# %%
print(a)
# Out:
# [1, 'python', 30.4, 30, 'hola']

# %%
a += [30, 'hola']

# %%
print(a)
# Out:
# [1, 'python', 30.4, 30, 'hola', 30, 'hola']

# %%
a += [
      
      [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]
      
      ]

# %%
print(a)
# Out:
# [1, 'python', 30.4, 30, 'hola', 30, 'hola', [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]]

# %%
b = ['Arjona', 'Coelho', 6]

# %%
print(b)
# Out:
# ['Arjona', 'Coelho', 6]

# %%
b * 2
# Out:
# ['Arjona', 'Coelho', 6, 'Arjona', 'Coelho', 6]

# %%
b *= 2.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-7f8f84eed291> in <module>()
# ----> 1 b *= 2.1
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print(b)
# Out:
# ['Arjona', 'Coelho', 6, 'Arjona', 'Coelho', 6]

# %%
# Seccionamiento

# %%
print(a)
# Out:
# [1, 'python', 30.4, 30, 'hola', 30, 'hola', [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]]

# %%
a[2]
# Out:
# 30.4

# %%
a[:3]
# Out:
# [1, 'python', 30.4]

# %%
print(a[::-1])
# Out:
# [[6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]], 'hola', 30, 'hola', 30, 30.4, 'python', 1]

# %%
a[-1]
# Out:
# [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]

# %%
a[-1]
# Out:
# [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]

# %%
c = a[-1]
print(c)
# Out:
# [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]

# %%
c[2]
# Out:
# 'bitcoin'

# %%
a[-1][2]
# Out:
# 'bitcoin'

# %%
a[-1]
# Out:
# [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]

# %%
a[-1][3][1][1]
# Out:
# 'cocodrilo'

# %%
# Mutabilidad

a
# Out:
# [1,
#  'python',
#  30.4,
#  30,
#  'hola',
#  30,
#  'hola',
#  [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]]

# %%
print(a)
# Out:
# [1, 'python', 30.4, 30, 'hola', 30, 'hola', [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]]

# %%
a[0] = 'casa'

# %%
print(a)
# Out:
# ['casa', 'python', 30.4, 30, 'hola', 30, 'hola', [6, 54.87, 'bitcoin', [2, (2, 'cocodrilo')]]]

# %%
cadena1 = 'inmutable'
cadena2 = 'inmutable'

print(id(cadena1), id(cadena2))
# Out:
# 140701534522992 140701534522992

# %%
lista1 = [1, 2, 3]
lista2 = [1, 2, 3]

print(id(lista1), id(lista2))
# Out:
# 140701534520008 140701534519560

# %%
lista1[0] = 1729

# %%
print(lista1, lista2)
# Out:
# [1729, 2, 3] [1, 2, 3]

# %%
lista3 = lista1

# %%
print(lista3)
# Out:
# [1729, 2, 3]

# %%
print(id(lista1), id(lista3))
# Out:
# 140701534520008 140701534520008

# %%
lista1[0] = 1

# %%
print(lista1, lista3)
# Out:
# [1, 2, 3] [1, 2, 3]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
lista3 = list(lista1)

# %%
print(lista1, lista3)
# Out:
# [1, 2, 3] [1, 2, 3]

# %%
print(id(lista1), id(lista3))
# Out:
# 140701534520008 140701534476616

# %%
lista1[0] = 'caracas'

# %%
print(lista1, lista3)
# Out:
# ['caracas', 2, 3] [1, 2, 3]

# %%
import random

minusculas = 'abcdefghijklmnopqrstuvwxyz' # No aparece la ñ
mayusculas = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
numeros = '0123456789'
simbolos = '''!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"'''

todo = minusculas + mayusculas + simbolos
longitud = 16
clave = "".join(random.sample(todo, longitud))
print(clave)
# Out:
# ,$u^Y%q/e}{"y-#&

# %%
from string import digits, punctuation, ascii_letters

todo = ascii_letters + digits + punctuation
clave = "".join(random.sample(todo, longitud))

# %%
print(clave)
# Out:
# )a1?^wV+x%p}B6:X

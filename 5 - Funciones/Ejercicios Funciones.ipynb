# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# Un isógrama es una palabra que no tiene letras repetidas. Implementa una función que determine si una cadena de caracteres que contiene *solo letras* es o no un isógrama. Su función deberá devolver `True` o `False`. Asuma que una cadena de carácter vacía es un isógrama y además ignore las mayúsculas.
#
# ```
# Funcion("Cambur" ) -> True
# Funcion("Aba" ) -> False
# Funcion("CaRAcaS" ) -> False
# ```

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# Jaden Smith, hijo de Will Smith, es el protagonista de películas como The Karate Kid (2010) y After Earth (2013). Jaden también es conocido por su filosofía que transmite a través de Twitter. Cuando él escribe en Twitter, casi siempre usa mayúsculas en cada palabra, por ejemplo:
#
# `"How Can Mirrors Be Real If Our Eyes Aren't Real"`
#
# Tu tarea será crear una función que sea capaz de convertir cualquier cadena de caracteres a cómo las escribiría Jaden Smith.

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# Se te proporciona una lista (que tendrá una longitud de al menos 3 unidades, pero podría ser muy grande) que contiene números enteros. La lista estará compuesta por únicamente `enteros impares` o enteramente compuesta por `enteros pares` **excepto por un único entero N**. Escriba una función que tome la lista como argumento y devuelva este "valor atípico" N.
#
# `[2, 4, 0, 100, 4, 11, 2602, 36]`
#
# Deberá devolver: 11 (el único número impar)
#
# ---
#
# `[160, 3, 1719, 19, 11, 13, -21]`
#
# Deberá devolver: 160 (el único número par)

# %% [markdown]
# # Ejercicio 4

# %% [markdown]
# Crea una función para que convierta una cadena palabras delimitadas por guiones y/o guiones bajos al estilo **camelCase**.
#
# `Funcion("El-guerrero-de-Acero")`
#
# Devolverá: `"elGuerreroDeAcero"`
#
# `Funcion("el_guerrero_dorado")`
#
# Devolverá: `"elGuerreroDorado"`
#
#
# ***Considere también que una misma cadena de palabras puede estar delimitada tanto por guiones como guiones bajos.***
#
# `"Los-Caballeros_del_Zodiaco"`

# %% [markdown]
# # Ejercicio 5

# %% [markdown]
# Escribe una función en Python que reciba dos listas, `lista1` y `lista2`. Ambas listas van a contener única y exclusivamente palabras. La cuestión es que la `lista2` va a contener palabras que se hayan formado utilizando a lo sumo una palabra de la `lista1`. Tu función deberá devolver la(s) palabra(s) de la `lista1` se usaron para formar la(s) palabra(s) de la `lista2`.
#
# Ejemplo:
#
#
# ```
# Entrada:
#
# lista1 = ['logo', 'logo', 'mar', ella]
# lista2 = ["maravilla", "dermatólogo", "carne", "altamar", "botella"]
# ```
#
#
#
# ```
# Salida:
# ['logo', 'mar', 'ella']
# ```

# %% [markdown]
# # Ejercicio 6

# %% [markdown]
# Crea un programa en Python que sea capaz de ordenar la siguiente lista de cadenas de caracteres de manera alfabética, pero colocando de primero aquellas palabras que comiencen con M hasta las que comienzan con la Z y luego de las que comienzan con la A hasta la L.
#
#
# ```
# lista = ['Ronny', 'Andrés', 'Génesis', 'Paola', 'Alejandra', 'María',
#          'Álvaro','Víctor','Zaira','Silvia','Marta', 'Queen', 'Azucena',
#          'Laura','Javier','Raúl','Añua', 'Óliver', 'Nina', 'Tony', 'Ximena',
#          'Yolanda', 'Ernesto', 'Carlos', 'Daniela', 'Grecia',
#          'Hector', 'Inés', 'Katherine', 'Luis', 'Barbara', 'Federico']
# ```
#
# Salida de tu función:
#
#
# ```
# ['María', 'Marta', 'Nina', 'Óliver', 'Paola', 'Queen', 'Raúl', 'Ronny',
# 'Silvia', 'Tony', 'Víctor', 'Ximena', 'Yolanda', 'Zaira', 'Alejandra',
# 'Álvaro', 'Andrés', 'Azucena', 'Añua', 'Barbara', 'Carlos', 'Daniela',
# 'Ernesto', 'Federico', 'Génesis', 'Grecia', 'Hector', 'Inés', 'Javier'
# 'Katherine', 'Laura', 'Luis']
# ```

# %% [markdown]
# # Ejercicio 7

# %% [markdown]
# Escriba un programa en Python que valide contraseñas a la hora de elegir una.
#
# Su programa deberá comprobar que la contraseña tenga:
#
# *   Entre 6 y 12 caracteres.
# *   Al menos un dígito.
# *   Al menos una mayúscula.
# *   Al menos una minúscula.
# *   Al menos un carácter especial.
#
# Si alguno de los requisitos no se cumple, informará de ese requisito, pero sólo
# del primero de los requisitos que no se cumpla.

# %% [markdown]
# # Ejercicio 8

# %% [markdown]
# El impuesto que una persona debe pagar, en los Estados Unidos, es calculado con base en su estado civil y sus ingresos. Hay 4 estados definidos:
#
#
#
# 1.   Contribuyentes individuales.
# 2.   Contribuyentes casados que presentan una declaración conjunta.
# 3.   Contribuyentes casados que presentan una declaración separada.
# 4.   Cabeza de hogar.
#
# Las tasas de impuestos varían cada año. La siguiente tabla muestra las tasas para el año 2009.
#
#
# ---
#
#
# | Tasa de impuesto (%) |     Individual    | Casado con declaración conjunta | Casado con declaración separada |   Cabeza de hogar   |
# |:--------------------:|:-----------------:|:-------------------------------:|:-------------------------------:|:-------------------:|
# |          10%         |    [\$0 - \$8350]   |          [\$0 - \$16700]         |           [\$0 - \$8350]          |    [\$0 - \$11950]   |
# |          15%         | (\$8350 - \$33950] |       (\$16700 - \$67900]       |        (\$8350 - \$33950]        | (\$11950 - \$45500] |
# |          25%         | (\$33950 - \$82250] |       (\$67900 - \$137050]       |        (\$33950 - \$68525]        | (\$45500 - \$117450] |
# |          28%         | \$82250 o más |       \$137050 o más       |        \$68525 o más        | \$117450 o más |
#
#
#
# ---
#
#
# Por ejemplo, si eres contribuyente individual y tus ingresos son de \$10000, los primeros \$8350 son gravados al 10% y los otros \$1650 son gravados al 15%. Entonces, el impuesto a pagar es de \$1082.5.
#
# Otro ejemplo sería, si eres contribuyente individual y tus ingresos son de \$70000, los primeros \$8350 son gravados al 10%, \$25600 son gravados al 15% y los otros \$36050 son gravados al 25%. Entonces el impuesto a pagar es de \$13687.5.
#
#
# ---
#
#
# Crea un programa en Python que automatice esta tarea. El usuario debe ingresar su tipo de estado y sus ingresos, y con base en esos datos calcular e imprimir los impuestos que debe pagar.
#
# A continuación, se presenta una tabla **para que verifique los resultados de su programa:**
#
# |          Tipo de estado         | Ingresos | Impuestos a pagar |
# |:-------------------------------:|:--------:|:-----------------:|
# |            Individual           |   \$20000  |        \$200        |
# |            Individual           |   \$70000  |      \$13687.5      |
# | Casado con declaración conjunta |   \$80000  |       \$12375       |
# | Casado con declaración conjunta |   \$90000  |       \$14875       |
# | Casado con declaración separada |   \$97500  |      \$21431.75     |
# |         Cabeza de hogar         |  \$120000  |       \$24929       |
#
# **Pista: Debes deducir la formula para el cálculo de los impuestos.**

# %%
bool(1)
# Out:
# True

# %%
bool(2)
# Out:
# True

# %%
bool(-2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1.41)
# Out:
# True

# %%
bool(0.0)
# Out:
# False

# %%
bool('')
# Out:
# False

# %%
bool(' ')
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([1])
# Out:
# True

# %%
bool([0])
# Out:
# True

# %%
bool({})
# Out:
# False

# %%
bool({'hola': 'ronny'})
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
# Devolverá verdadero si y solo sí existe al menos un elemento 
# en un iterable cuyo valor bool devuelva verdadero.

any([0, None, '', (), 1])
# Out:
# True

# %%
clave = 'Hje214*^@'

# %%
lista = [True if elemento.isdigit() else False for elemento in clave]
lista
# Out:
# [False, False, False, True, True, True, False, False, False]

# %%
any(lista)
# Out:
# True

# %%
# Devolverá falso si y solo sí existe al menos un elemento 
# en un iterable cuyo valor bool devuelva falso.
all([1, 2, 3, 4, 5, 0])
# Out:
# False
